# %% [markdown]
# <a href="https://colab.research.google.com/github/huhdavid/w207-final-project/blob/main/Final_Group_Project_House_Prices_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # House Prices - Advanced Regression Techniques
#
# ## https://www.kaggle.com/c/house-prices-advanced-regression-techniques
#
# ## Team: Matt White, Heather Reed, David Huh

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8c0a7689-9986-4f54-b384-db7aa5d58ea1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8c0a7689-9986-4f54-b384-db7aa5d58ea1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
import numpy as np
import pandas as pd
import io

# %%
sample_submission = pd.read_csv(io.BytesIO(uploaded['sample_submission.csv']))
test = pd.read_csv(io.BytesIO(uploaded['test.csv']))
train = pd.read_csv(io.BytesIO(uploaded['train.csv']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-58dc47bd2b34> in <module>()
# ----> 1 sample_submission = pd.read_csv(io.BytesIO(uploaded['sample_submission.csv']))
#       2 test = pd.read_csv(io.BytesIO(uploaded['test.csv']))
#       3 train = pd.read_csv(io.BytesIO(uploaded['train.csv']))
#
# KeyError: 'sample_submission.csv'

# %%
sample_submission.head(3)
# Out:
#      Id      SalePrice
# 0  1461  169277.052498
# 1  1462  187758.393989
# 2  1463  183583.683570

# %%
test.head(3)
# Out:
#      Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0  1461          20       RH  ...    2010        WD        Normal
# 1  1462          20       RL  ...    2010        WD        Normal
# 2  1463          60       RL  ...    2010        WD        Normal
#
# [3 rows x 80 columns]

# %%
train.head(10)
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
# 5   6          50       RL  ...        WD         Normal    143000
# 6   7          20       RL  ...        WD         Normal    307000
# 7   8          60       RL  ...        WD         Normal    200000
# 8   9          50       RM  ...        WD        Abnorml    129900
# 9  10         190       RL  ...        WD         Normal    118000
#
# [10 rows x 81 columns]

# %% [markdown]
# Baseline model:
